# %% [markdown]
# # Plot two recurrence plots with colorbar

# %%
from thebeat.core import Sequence
import matplotlib.pyplot as plt
import matplotlib as mpl
from thebeat.visualization import recurrence_plot

fig, axs = plt.subplots(1, 2)

seq1 = Sequence.generate_random_normal(n_events=10, mu=500, sigma=50, end_with_interval=True) * 10
seq2 = Sequence.generate_random_normal(n_events=10, mu=500, sigma=50, end_with_interval=True) * 10

recurrence_plot(seq1, ax=axs[0])
recurrence_plot(seq1, ax=axs[1])

fig.colorbar(mpl.cm.ScalarMappable(), ax=axs, fraction=0.02, pad=0.1)
fig.show()
# Out:
# /var/folders/lp/b5jvvgsj5rxdd7kkdd08mdy00000gn/T/ipykernel_60243/1169408549.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
